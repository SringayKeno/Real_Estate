# %% [markdown]
# # Description
#
# This Notebook is trying to train a dataset of the middle tier of hoursing price in US metro breakdown with Random Forest Regression. We have the location info as States, and the July price of 2021 and 2020. We want to predict the housing price of July 2022

# %%
import numpy as np 
import pandas as pd
import pymongo
from pymongo import MongoClient

from sklearn.model_selection import train_test_split
from rfpimp import *
from sklearn.ensemble import RandomForestRegressor
import statistics

from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_absolute_error

# Functions we can use later

#from sklearn.metrics import accuracy_score
#import tensorflow as tf
#from sklearn.preprocessing import StandardScaler,OneHotEncoder

# %% [markdown]
# # I. Connect the Database

# %%
# Connect Mongodb with Jupyter 
# https://gist.github.com/gabefair/a28f77e3899b98f042ac74e17380fe24

client=MongoClient('localhost',27017)

# %%
db=client['FinalProject']

# %%
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'FinalProject')

# %%
allDataconn=db['Metro_Mid_All_updated_final']
allDataCursor=allDataconn.find()
AllData_df=pd.DataFrame(list(allDataCursor))

# %%
AllData_df
# Out:
#                           _id  RegionID                       RegionName  \
# 0    6306af830eac8f01d7192653    394297                     Aberdeen, SD
# 1    6306af830eac8f01d7192654    394298                     Aberdeen, WA
# 2    6306af830eac8f01d7192655    394299                      Abilene, TX
# 3    6306af830eac8f01d7192656    394300                          Ada, OK
# 4    6306af830eac8f01d7192657    394302                       Adrian, MI
# ..                        ...       ...                              ...
# 902  6306af840eac8f01d71929d9    753925               Vineyard Haven, MA
# 903  6306af840eac8f01d71929da    753926                  Weatherford, OK
# 904  6306af840eac8f01d71929db    753927                   Winnemucca, NV
# 905  6306af840eac8f01d71929dc    753928  Wisconsin Rapids-Marshfield, WI
# 906  6306af840eac8f01d71929dd    753929                       Zapata, TX
#
#     Statename  julyvalue16  julyvalue17  julyvalue18  julyvalue19  \
# 0          SD       150756       160313       168185       173277
# 1          WA       143058       155767       174051       192211
# 2          TX       119201       123626       131428       136147
# 3          OK        94179        96676       103013        99878
# 4          MI       132336       145224       151872       159528
# ..        ...          ...          ...          ...          ...
# 902        MA       724302       770010       807091       840047
# 903        OK       118489       112530       113738       114721
# 904        NV       207449       219834       242939       248047
# 905        WI       107686       113290       120168       126189
# 906        TX        80117        86551        88231        93364
#
#      julyvalue20  julyvalue21  ...  PopMale20  PopFemale20  MedianAge20  \
# 0         175803       192832  ...    20937.0      21250.0         38.3
# 1         217648       274100  ...    38877.0      36934.0         44.4
# 2         141065       158980  ...    89408.0      87401.0         34.2
# 3         104325       116926  ...    18620.0      19457.0         35.9
# 4         165701       189462  ...    50413.0      48801.0         41.9
# ..           ...          ...  ...        ...          ...          ...
# 902       860818       991822  ...    10173.0      10408.0         48.8
# 903       118732       128883  ...    14241.0      14182.0         31.6
# 904       247928       271344  ...     9025.0       8258.0         36.2
# 905       128885       150185  ...    36871.0      37220.0         43.6
# 906        95336       104933  ...     6963.0       6921.0         30.4
#
#      MedianAgeMale20  medianAgeFemale20     pop21  PopMale21  PopFemale21  \
# 0               37.7               39.0   42134.0    20903.0      21231.0
# 1               43.2               45.8   76841.0    39448.0      37393.0
# 2               33.2               35.2  177314.0    89671.0      87643.0
# 3               34.9               37.0   38163.0    18561.0      19602.0
# 4               40.5               43.6   98956.0    50297.0      48659.0
# ..               ...                ...       ...        ...          ...
# 902             47.5               50.0   21097.0    10397.0      10700.0
# 903             30.9               32.3   28163.0    14064.0      14099.0
# 904             36.6               35.7   17648.0     9167.0       8481.0
# 905             42.4               44.9   74070.0    36855.0      37215.0
# 906             28.5               32.2   13908.0     6949.0       6959.0
#
#      MedianAgeMale21  MedianAgeFemale21
# 0               38.0               39.2
# 1               43.5               45.9
# 2               33.5               35.3
# 3               35.0               36.9
# 4               40.8               43.7
# ..               ...                ...
# 902             47.7               50.0
# 903             30.7               32.6
# 904             36.7               35.6
# 905             42.5               44.9
# 906             28.6               32.6
#
# [907 rows x 30 columns]

# %%
AllData_df.nunique()
# Out:
# _id                  907
# RegionID             907
# RegionName           907
# Statename             51
# julyvalue16          882
# julyvalue17          881
# julyvalue18          890
# julyvalue19          898
# julyvalue20          895
# julyvalue21          900
# Janvalue22           903
# febvalue22           902
# marchvalue22         904
# aprvalue22           905
# mayvalue22           905
# junevalue22          906
# julyvalue22          907
# JulyListings22       427
# JulyInv22            546
# pop20                887
# PopMale20            887
# PopFemale20          885
# MedianAge20          220
# MedianAgeMale20      204
# medianAgeFemale20    221
# pop21                886
# PopMale21            888
# PopFemale21          884
# MedianAgeMale21      210
# MedianAgeFemale21    229
# dtype: int64

# %% [markdown]
# # II. Process the Data

# %%
merge_df=AllData_df.drop(columns=['_id'])
merge_df=merge_df.dropna(how='any')
print(merge_df.shape)
merge_df.head()
# Out:
# (884, 29)
#    RegionID    RegionName Statename  julyvalue16  julyvalue17  julyvalue18  \
# 0    394297  Aberdeen, SD        SD       150756       160313       168185
# 1    394298  Aberdeen, WA        WA       143058       155767       174051
# 2    394299   Abilene, TX        TX       119201       123626       131428
# 3    394300       Ada, OK        OK        94179        96676       103013
# 4    394302    Adrian, MI        MI       132336       145224       151872
#
#    julyvalue19  julyvalue20  julyvalue21  Janvalue22  ...  PopMale20  \
# 0       173277       175803       192832      202526  ...    20937.0
# 1       192211       217648       274100      318556  ...    38877.0
# 2       136147       141065       158980      172185  ...    89408.0
# 3        99878       104325       116926      127384  ...    18620.0
# 4       159528       165701       189462      210403  ...    50413.0
#
#    PopFemale20  MedianAge20  MedianAgeMale20  medianAgeFemale20     pop21  \
# 0      21250.0         38.3             37.7               39.0   42134.0
# 1      36934.0         44.4             43.2               45.8   76841.0
# 2      87401.0         34.2             33.2               35.2  177314.0
# 3      19457.0         35.9             34.9               37.0   38163.0
# 4      48801.0         41.9             40.5               43.6   98956.0
#
#    PopMale21  PopFemale21  MedianAgeMale21  MedianAgeFemale21
# 0    20903.0      21231.0             38.0               39.2
# 1    39448.0      37393.0             43.5               45.9
# 2    89671.0      87643.0             33.5               35.3
# 3    18561.0      19602.0             35.0               36.9
# 4    50297.0      48659.0             40.8               43.7
#
# [5 rows x 29 columns]

# %%
merge_df.dtypes
# Out:
# RegionID               int64
# RegionName            object
# Statename             object
# julyvalue16            int64
# julyvalue17            int64
# julyvalue18            int64
# julyvalue19            int64
# julyvalue20            int64
# julyvalue21            int64
# Janvalue22             int64
# febvalue22             int64
# marchvalue22           int64
# aprvalue22             int64
# mayvalue22             int64
# junevalue22            int64
# julyvalue22            int64
# JulyListings22       float64
# JulyInv22              int64
# pop20                float64
# PopMale20            float64
# PopFemale20          float64
# MedianAge20          float64
# MedianAgeMale20      float64
# medianAgeFemale20    float64
# pop21                float64
# PopMale21            float64
# PopFemale21          float64
# MedianAgeMale21      float64
# MedianAgeFemale21    float64
# dtype: object

# %% [markdown]
# ### 1. Change the datatypes and add more feature columns

# %%
MedianAge21=(merge_df['MedianAgeMale21']+ merge_df['MedianAgeFemale21'])/2
merge_df['MedianAge21']=MedianAge21

#Format the value to have fewer unique numbers for future grouping
merge_df['MedianAge21'] = merge_df['MedianAge21'].map("{:.1f}".format).astype(float)
merge_df
# Out:
#      RegionID                       RegionName Statename  julyvalue16  \
# 0      394297                     Aberdeen, SD        SD       150756
# 1      394298                     Aberdeen, WA        WA       143058
# 2      394299                      Abilene, TX        TX       119201
# 3      394300                          Ada, OK        OK        94179
# 4      394302                       Adrian, MI        MI       132336
# ..        ...                              ...       ...          ...
# 902    753925               Vineyard Haven, MA        MA       724302
# 903    753926                  Weatherford, OK        OK       118489
# 904    753927                   Winnemucca, NV        NV       207449
# 905    753928  Wisconsin Rapids-Marshfield, WI        WI       107686
# 906    753929                       Zapata, TX        TX        80117
#
#      julyvalue17  julyvalue18  julyvalue19  julyvalue20  julyvalue21  \
# 0         160313       168185       173277       175803       192832
# 1         155767       174051       192211       217648       274100
# 2         123626       131428       136147       141065       158980
# 3          96676       103013        99878       104325       116926
# 4         145224       151872       159528       165701       189462
# ..           ...          ...          ...          ...          ...
# 902       770010       807091       840047       860818       991822
# 903       112530       113738       114721       118732       128883
# 904       219834       242939       248047       247928       271344
# 905       113290       120168       126189       128885       150185
# 906        86551        88231        93364        95336       104933
#
#      Janvalue22  ...  PopFemale20  MedianAge20  MedianAgeMale20  \
# 0        202526  ...      21250.0         38.3             37.7
# 1        318556  ...      36934.0         44.4             43.2
# 2        172185  ...      87401.0         34.2             33.2
# 3        127384  ...      19457.0         35.9             34.9
# 4        210403  ...      48801.0         41.9             40.5
# ..          ...  ...          ...          ...              ...
# 902     1079642  ...      10408.0         48.8             47.5
# 903      138100  ...      14182.0         31.6             30.9
# 904      291286  ...       8258.0         36.2             36.6
# 905      162435  ...      37220.0         43.6             42.4
# 906      112190  ...       6921.0         30.4             28.5
#
#      medianAgeFemale20     pop21  PopMale21  PopFemale21  MedianAgeMale21  \
# 0                 39.0   42134.0    20903.0      21231.0             38.0
# 1                 45.8   76841.0    39448.0      37393.0             43.5
# 2                 35.2  177314.0    89671.0      87643.0             33.5
# 3                 37.0   38163.0    18561.0      19602.0             35.0
# 4                 43.6   98956.0    50297.0      48659.0             40.8
# ..                 ...       ...        ...          ...              ...
# 902               50.0   21097.0    10397.0      10700.0             47.7
# 903               32.3   28163.0    14064.0      14099.0             30.7
# 904               35.7   17648.0     9167.0       8481.0             36.7
# 905               44.9   74070.0    36855.0      37215.0             42.5
# 906               32.2   13908.0     6949.0       6959.0             28.6
#
#      MedianAgeFemale21  MedianAge21
# 0                 39.2         38.6
# 1                 45.9         44.7
# 2                 35.3         34.4
# 3                 36.9         36.0
# 4                 43.7         42.2
# ..                 ...          ...
# 902               50.0         48.9
# 903               32.6         31.6
# 904               35.6         36.2
# 905               44.9         43.7
# 906               32.6         30.6
#
# [884 rows x 30 columns]

# %% [markdown]
# ### 2. Change the Category column of `Statename` to numbers.

# %%
#numbers=[*range(1,52,1)] 
# dict={states[i]: numbers[i] for i in range(len(states))}

states=merge_df["Statename"].unique().tolist()

dict={states[i]: i for i in range(len(states))} 

dict
# Out:
# {'SD': 0,
#  'WA': 1,
#  'TX': 2,
#  'OK': 3,
#  'MI': 4,
#  'OH': 5,
#  'NM': 6,
#  'GA': 7,
#  'OR': 8,
#  'NY': 9,
#  'MN': 10,
#  'AL': 11,
#  'LA': 12,
#  'PA': 13,
#  'IA': 14,
#  'AK': 15,
#  'IN': 16,
#  'WI': 17,
#  'FL': 18,
#  'AR': 19,
#  'NC': 20,
#  'KS': 21,
#  'TN': 22,
#  'NJ': 23,
#  'ME': 24,
#  'CA': 25,
#  'MD': 26,
#  'MA': 27,
#  'VT': 28,
#  'NE': 29,
#  'WV': 30,
#  'SC': 31,
#  'NH': 32,
#  'MT': 33,
#  'ND': 34,
#  'ID': 35,
#  'VA': 36,
#  'CO': 37,
#  'KY': 38,
#  'MO': 39,
#  'CT': 40,
#  'MS': 41,
#  'IL': 42,
#  'NV': 43,
#  'WY': 44,
#  'UT': 45,
#  'DE': 46,
#  'AZ': 47,
#  'HI': 48,
#  'RI': 49,
#  'DC': 50}

# %%
# merge_df=month_df.merge(julyhome, on='RegionID', how='left')
merge_df['StateCode']=merge_df['Statename'].map(dict)
merge_df=merge_df.dropna()
merge_df
# Out:
#      RegionID                       RegionName Statename  julyvalue16  \
# 0      394297                     Aberdeen, SD        SD       150756
# 1      394298                     Aberdeen, WA        WA       143058
# 2      394299                      Abilene, TX        TX       119201
# 3      394300                          Ada, OK        OK        94179
# 4      394302                       Adrian, MI        MI       132336
# ..        ...                              ...       ...          ...
# 902    753925               Vineyard Haven, MA        MA       724302
# 903    753926                  Weatherford, OK        OK       118489
# 904    753927                   Winnemucca, NV        NV       207449
# 905    753928  Wisconsin Rapids-Marshfield, WI        WI       107686
# 906    753929                       Zapata, TX        TX        80117
#
#      julyvalue17  julyvalue18  julyvalue19  julyvalue20  julyvalue21  \
# 0         160313       168185       173277       175803       192832
# 1         155767       174051       192211       217648       274100
# 2         123626       131428       136147       141065       158980
# 3          96676       103013        99878       104325       116926
# 4         145224       151872       159528       165701       189462
# ..           ...          ...          ...          ...          ...
# 902       770010       807091       840047       860818       991822
# 903       112530       113738       114721       118732       128883
# 904       219834       242939       248047       247928       271344
# 905       113290       120168       126189       128885       150185
# 906        86551        88231        93364        95336       104933
#
#      Janvalue22  ...  MedianAge20  MedianAgeMale20  medianAgeFemale20  \
# 0        202526  ...         38.3             37.7               39.0
# 1        318556  ...         44.4             43.2               45.8
# 2        172185  ...         34.2             33.2               35.2
# 3        127384  ...         35.9             34.9               37.0
# 4        210403  ...         41.9             40.5               43.6
# ..          ...  ...          ...              ...                ...
# 902     1079642  ...         48.8             47.5               50.0
# 903      138100  ...         31.6             30.9               32.3
# 904      291286  ...         36.2             36.6               35.7
# 905      162435  ...         43.6             42.4               44.9
# 906      112190  ...         30.4             28.5               32.2
#
#         pop21  PopMale21  PopFemale21  MedianAgeMale21  MedianAgeFemale21  \
# 0     42134.0    20903.0      21231.0             38.0               39.2
# 1     76841.0    39448.0      37393.0             43.5               45.9
# 2    177314.0    89671.0      87643.0             33.5               35.3
# 3     38163.0    18561.0      19602.0             35.0               36.9
# 4     98956.0    50297.0      48659.0             40.8               43.7
# ..        ...        ...          ...              ...                ...
# 902   21097.0    10397.0      10700.0             47.7               50.0
# 903   28163.0    14064.0      14099.0             30.7               32.6
# 904   17648.0     9167.0       8481.0             36.7               35.6
# 905   74070.0    36855.0      37215.0             42.5               44.9
# 906   13908.0     6949.0       6959.0             28.6               32.6
#
#      MedianAge21  StateCode
# 0           38.6          0
# 1           44.7          1
# 2           34.4          2
# 3           36.0          3
# 4           42.2          4
# ..           ...        ...
# 902         48.9         27
# 903         31.6          3
# 904         36.2         43
# 905         43.7         17
# 906         30.6          2
#
# [884 rows x 31 columns]

# %%
merge_df.nunique()
# Out:
# RegionID             884
# RegionName           884
# Statename             51
# julyvalue16          862
# julyvalue17          860
# julyvalue18          869
# julyvalue19          875
# julyvalue20          872
# julyvalue21          877
# Janvalue22           880
# febvalue22           879
# marchvalue22         881
# aprvalue22           882
# mayvalue22           882
# junevalue22          883
# julyvalue22          884
# JulyListings22       425
# JulyInv22            539
# pop20                882
# PopMale20            882
# PopFemale20          880
# MedianAge20          220
# MedianAgeMale20      203
# medianAgeFemale20    221
# pop21                881
# PopMale21            883
# PopFemale21          879
# MedianAgeMale21      210
# MedianAgeFemale21    229
# MedianAge21          210
# StateCode             51
# dtype: int64

# %%
merge_df.dtypes
# Out:
# RegionID               int64
# RegionName            object
# Statename             object
# julyvalue16            int64
# julyvalue17            int64
# julyvalue18            int64
# julyvalue19            int64
# julyvalue20            int64
# julyvalue21            int64
# Janvalue22             int64
# febvalue22             int64
# marchvalue22           int64
# aprvalue22             int64
# mayvalue22             int64
# junevalue22            int64
# julyvalue22            int64
# JulyListings22       float64
# JulyInv22              int64
# pop20                float64
# PopMale20            float64
# PopFemale20          float64
# MedianAge20          float64
# MedianAgeMale20      float64
# medianAgeFemale20    float64
# pop21                float64
# PopMale21            float64
# PopFemale21          float64
# MedianAgeMale21      float64
# MedianAgeFemale21    float64
# MedianAge21          float64
# StateCode              int64
# dtype: object

# %%
#  merge_df['July22NewListingNo.'] = merge_df['July22NewListingNo.'].fillna(0)
#  merge_df['July22Inventory'] = merge_df['July22Inventory'].fillna(0)

# merge_df['July22NewListingNo.'] = merge_df['July22NewListingNo.'].astype(int)
# merge_df['July22Inventory'] = merge_df['July22Inventory'].astype(int)
# merge_df.dtypes

# %%
merge_df.to_csv('merged_data_mongodb.csv')

# %% [markdown]
# # III. Random Forest Model Training
#
# ## 1st training:
# ### Statecode+2 previous years' July Data

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

X, y = merge_df[['StateCode','julyvalue20','julyvalue21']], merge_df['julyvalue22']

# %%
# Only Tran the model
rf = RandomForestRegressor(n_estimators=100) 
rf.fit(X, y)

predictions = rf.predict(X)
e = mean_absolute_error(y, predictions)
ep = e*100.0/y.mean()
print(f"${e:.0f} average error; {ep:.2f}% error")
# Out:
# $4636 average error; 1.73% error

# %%
# Train and Test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) 

rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)


validation_e = mean_absolute_error(y_test, rf.predict(X_test))
print(f"${validation_e:.0f} average error; {validation_e*100.0/y.mean():.2f}% error")
# Out:
# $13802 average error; 5.15% error

# %%
rf = RandomForestRegressor(n_estimators=100,
                           n_jobs=-1,
                           oob_score=True)   # get error estimate
rf.fit(X_train, y_train)
noisy_oob_r2 = rf.oob_score_
print(f"OOB score {noisy_oob_r2:.4f}")
# Out:
# OOB score 0.9770

# %% [markdown]
# ##### Importance

# %%
from rfpimp import *
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
I = importances(rf, X_test, y_test)
I
# Out:
#              Importance
# Feature
# julyvalue21    1.418876
# julyvalue20    0.082676
# StateCode      0.001140

# %%
plot_importances(I, color='#4575b4', vscale=1.8)

# %% [markdown]
# ## 2nd training:
# ### Statecode+2 previous years' July Data + 3 most recent month

# %%
X, y = merge_df[['StateCode','julyvalue20','julyvalue21','aprvalue22','mayvalue22','junevalue22']], merge_df['julyvalue22']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) 

rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)


validation_e = mean_absolute_error(y_test, rf.predict(X_test))
print(f"${validation_e:.0f} average error; {validation_e*100.0/y.mean():.2f}% error")
# Out:
# $5624 average error; 2.10% error

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) 

rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)


validation_e = mean_absolute_error(y_test, rf.predict(X_test))
print(f"${validation_e:.0f} average error; {validation_e*100.0/y.mean():.2f}% error")
# Out:
# $2695 average error; 1.01% error

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
I = importances(rf, X_test, y_test)
I
# Out:
#              Importance
# Feature
# junevalue22    0.656514
# mayvalue22     0.132721
# aprvalue22     0.047402
# julyvalue20    0.008477
# julyvalue21    0.007016
# StateCode      0.000122

# %%
plot_importances(I, color='#4575b4', vscale=1.8)

# %% [markdown]
# ## 3rd training
# ### Every Feature (2021 population of total and different sex, homevalues, statecode, inventory and new listing homes)

# %%
y=merge_df['julyvalue22']
X=merge_df.drop(columns=['julyvalue22', 'RegionName','Statename', 'RegionID'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) 

rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)


validation_e = mean_absolute_error(y_test, rf.predict(X_test))
print(f"${validation_e:.0f} average error; {validation_e*100.0/y.mean():.2f}% error")
# Out:
# $4842 average error; 1.81% error

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
I = importances(rf, X_test, y_test)
I
# Out:
#                    Importance
# Feature
# junevalue22          0.564518
# mayvalue22           0.098659
# aprvalue22           0.042127
# marchvalue22         0.022020
# febvalue22           0.017752
# julyvalue21          0.009312
# Janvalue22           0.007883
# julyvalue20          0.007857
# julyvalue19          0.007098
# julyvalue17          0.002099
# julyvalue18          0.002045
# julyvalue16          0.001385
# PopMale20            0.000255
# PopFemale21          0.000223
# JulyListings22       0.000154
# JulyInv22            0.000050
# pop21                0.000044
# medianAgeFemale20    0.000037
# pop20                0.000025
# MedianAgeMale21      0.000008
# StateCode           -0.000004
# MedianAge20         -0.000006
# PopFemale20         -0.000008
# MedianAgeFemale21   -0.000017
# PopMale21           -0.000031
# MedianAgeMale20     -0.000068
# MedianAge21         -0.000349

# %%
plot_importances(I, color='#4575b4', vscale=1.8)

# %% [markdown]
# ## 4th Try Statecode+ 4 most recent month

# %%
X, y = merge_df[['StateCode', 'marchvalue22', 'aprvalue22','mayvalue22','junevalue22']], merge_df['julyvalue22']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) 

rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)

y_predict=rf.predict(X_test)

validation_e = mean_absolute_error(y_test, rf.predict(X_test))
print(f"${validation_e:.0f} average error; {validation_e*100.0/y.mean():.2f}% error")
# Out:
# $5032 average error; 1.88% error

# %%
plt.scatter(y_test, y_predict)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual Price vs Predicted Price')
plt.show()

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
I = importances(rf, X_test, y_test)
I
# Out:
#               Importance
# Feature
# junevalue22     0.635165
# mayvalue22      0.148484
# aprvalue22      0.077898
# marchvalue22    0.067671
# StateCode       0.000039

# %%
plot_importances(I, color='#4575b4', vscale=1.8)

# %% [markdown]
# # Find the baseline

# %%
df=merge_df[['marchvalue22','aprvalue22','mayvalue22','junevalue22','julyvalue22']]
df
# Out:
#      marchvalue22  aprvalue22  mayvalue22  junevalue22  julyvalue22
# 0          209063      211212      212133       214395       216573
# 1          332651      339953      345792       353609       358311
# 2          176223      178761      181031       182951       184174
# 3          131117      132288      133456       134573       135715
# 4          216074      220213      223724       227199       229720
# ..            ...         ...         ...          ...          ...
# 902       1087952     1084380     1090639      1100439      1110770
# 903        141498      142178      142515       143615       144966
# 904        303173      306944      308108       310600       313137
# 905        163006      164211      164969       168053       168525
# 906        115485      115749      115743       116724       117885
#
# [884 rows x 5 columns]

# %%
df.describe().round()
# Out:
#        marchvalue22  aprvalue22  mayvalue22  junevalue22  julyvalue22
# count         884.0       884.0       884.0        884.0        884.0
# mean       256047.0    259985.0    262883.0     265815.0     267954.0
# std        172977.0    176079.0    178787.0     180182.0     180367.0
# min             0.0     64569.0     64952.0      65436.0      65766.0
# 25%        150786.0    152726.0    154357.0     156491.0     157868.0
# 50%        200072.0    202412.0    205390.0     208073.0     210118.0
# 75%        304761.0    307067.0    310138.0     314315.0     317381.0
# max       1631649.0   1667441.0   1677762.0    1664787.0    1619785.0

# %%
#df.boxplot(column=['1','2','3','4','5'])

# %%
df.std(axis=1).describe()
# Out:
# count       884.000000
# mean       5011.021661
# std        7551.536342
# min         227.282863
# 25%        1940.924897
# 50%        3431.810951
# 75%        5872.038065
# max      166901.180450
# dtype: float64

# %%
# The Standard Deviation of each Metro Area between these specific months 
# (months features that bring the highest score)

std_row=df.std(axis=1)
stdRow_df=pd.DataFrame(std_row, columns=['StandardDeviation'])
stdRow_df['StandardDeviation'] = stdRow_df['StandardDeviation'].astype(float)
stdRow_df
# Out:
#      StandardDeviation
# 0          2899.718986
# 1         10298.578844
# 2          3202.443130
# 3          1815.384450
# 4          5438.429047
# ..                 ...
# 902       10719.353595
# 903        1360.137603
# 904        3768.474798
# 905        2424.479985
# 906         996.066865
#
# [884 rows x 1 columns]

# %%
stdRow_df.boxplot(column=['StandardDeviation'])
# Out:
# <AxesSubplot:>

# %%
# df2=merge_df[['julyvalue20', 'julyvalue21', 'aprvalue22','mayvalue22','junevalue22','julyvalue22']]

# # Get the Standandard Deviation of each row (STD of different months for each metro area)
# df2.std(axis=1).describe()

# %%
# std_row2=df2.std(axis=1)
# stdRow_df2=pd.DataFrame(std_row2, columns=['StandardDeviation'])
# stdRow_df2['StandardDeviation'] = stdRow_df2['StandardDeviation'].astype(float)
# stdRow_df2.head()

# %%
# stdRow_df2.boxplot(column=['StandardDeviation'])

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# # Visualization

# %%
import seaborn as sns
from scipy import stats
from scipy.stats import norm

sns.distplot(stdRow_df['StandardDeviation'], fit=norm);
fig = plt.figure()
res = stats.probplot(stdRow_df['StandardDeviation'], plot=plt)
# Out:
# /Users/bibowang/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
july2022 = merge_df['7/31/22']
avg_price=july2022.mean()
print(f'Average housing price in the United States is ${avg_price}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '7/31/22'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/hn/wqbf79yx29zc_tn0g4b9jz7w0000gn/T/ipykernel_48113/1295005765.py in <module>
# ----> 1 july2022 = merge_df['7/31/22']
#       2 avg_price=july2022.mean()
#       3 print(f'Average housing price in the United States is ${avg_price}')
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: '7/31/22'

# %%
bystate=merge_df.groupby(['StateName']).mean()
bystate=bystate.reset_index()
bystate.head()

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# bystate.plot(kind="bar", color="red")
bystate.plot.bar('StateName','7/31/22', style='-o')
plt.xlabel('StateName', size=18)
plt.ylabel('USD', size=18)
plt.xticks(rotation=90,size=16)
plt.yticks(size=16)
plt.title("Average Middle Tier Housing Price By States of July 2022", size=20)
plt.rcParams["figure.figsize"] = (20,8)
plt.show()

# %%
sns.distplot(bystate['7/31/22'], fit=norm);
fig = plt.figure()
res = stats.probplot(bystate['7/31/22'], plot=plt)
